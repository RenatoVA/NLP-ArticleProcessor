# %%
import ollama
from langchain_community.llms import Ollama

# %%
llm=Ollama(model='llama3:8b',temperature=0.5)
respuesta=llm.invoke("Why the sky is blue?")
respuesta
# Out:
# ---------------------------------------------------------------------------
# ProtocolError                             Traceback (most recent call last)
# File c:\Users\renat\miniconda3\envs\llm\Lib\site-packages\requests\models.py:820, in Response.iter_content.<locals>.generate()
#     819 try:
# --> 820     yield from self.raw.stream(chunk_size, decode_content=True)
#     821 except ProtocolError as e:
#
# File c:\Users\renat\miniconda3\envs\llm\Lib\site-packages\urllib3\response.py:1057, in HTTPResponse.stream(self, amt, decode_content)
#    1056 if self.chunked and self.supports_chunked_reads():
# -> 1057     yield from self.read_chunked(amt, decode_content=decode_content)
#    1058 else:
#
# File c:\Users\renat\miniconda3\envs\llm\Lib\site-packages\urllib3\response.py:1206, in HTTPResponse.read_chunked(self, amt, decode_content)
#    1205 while True:
# -> 1206     self._update_chunk_length()
#    1207     if self.chunk_left == 0:
#
# ...
